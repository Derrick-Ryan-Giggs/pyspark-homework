# %%
import os
jar_path = os.path.abspath('lib/gcs-connector-hadoop3-latest.jar')
print(jar_path)
print(f"JAR exists: {os.path.exists(jar_path)}")
# Out:
# /mnt/storage/Desktop/DataEngineeringZoomcamp/PySpark/PySpark/lib/gcs-connector-hadoop3-latest.jar
# JAR exists: True

# %%
import os
from pyspark.sql import SparkSession

credentials_location = '/mnt/storage/Desktop/new-sa-key.json'
jar_path = '/mnt/storage/Desktop/DataEngineeringZoomcamp/PySpark/PySpark/lib/gcs-connector-hadoop3-latest.jar'

print(f"JAR exists: {os.path.exists(jar_path)}")
print(f"Credentials exist: {os.path.exists(credentials_location)}")

spark = SparkSession.builder \
    .master('local[*]') \
    .appName('gcs_test') \
    .config('spark.jars', jar_path) \
    .config('spark.hadoop.fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem') \
    .config('spark.hadoop.fs.AbstractFileSystem.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS') \
    .config('spark.hadoop.google.cloud.auth.service.account.enable', 'true') \
    .config('spark.hadoop.google.cloud.auth.service.account.json.keyfile', credentials_location) \
    .getOrCreate()

print(f"Spark version: {spark.version}")
# Out:
# JAR exists: True
# Credentials exist: True
# WARNING: Using incubator modules: jdk.incubator.vector
# 26/03/05 12:37:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/05 12:37:18 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark version: 4.1.1

# %%
df_yellow = spark.read.parquet(
    'gs://dtc-de-course-484520-terra-bucket/yellow_tripdata_2024-01.parquet',
    'gs://dtc-de-course-484520-terra-bucket/yellow_tripdata_2024-02.parquet',
    'gs://dtc-de-course-484520-terra-bucket/yellow_tripdata_2024-03.parquet',
)
df_yellow.show(5)
df_yellow.count()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# ...
